# %%
from viz_tools import *
from main import *
from config import *
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = prepare_data(filename)
# Out:
# Vocabulary {u'taxi': 0, u'anniversaire': 1, u'cambridge': 2, u'vie': 3, u'photo': 4, u'bforbank': 56, u'soldex': 6, u'cloture': 7, u'caltrain': 8, u'florence': 9, u'brunch': 10, u'italie': 18, u'airbnb': 26, u'creperie': 12, u'usa': 13, u'paris': 14, u'alimentaire': 15, u'cinema': 16, u'cantine': 17, u'virement': 11, u'location': 20, u'essence': 21, u'pret': 23, u'lasvegas': 24, u'zipcar': 25, u'bus': 27, u'retrait': 28, u'internet': 60, u'photos': 30, u'train': 31, u'lcl': 32, u'bar': 33, u'tricount': 34, u'hotel': 29, u'annuel': 79, u'cash': 36, u'mit': 64, u'lucile': 37, u'antony': 38, u'velo': 40, u'ratp': 41, u'vol': 42, u'coiffeur': 22, u'telephone': 44, u'livre': 67, u'skype': 46, u'interets': 73, u'cafe': 47, u'dininghall': 48, u'trip': 49, u'transport': 50, u'album': 51, u'voyage': 52, u'frais': 53, 'na': 54, u'avion': 55, u'ulock': 5, u'ava': 57, u'sncf': 58, u'maison': 59, u'peage': 39, u'achat': 61, u'abonnement': 62, u'tourisme': 63, u'loisirs': 19, u'assurance': 65, u'livret': 66, u'aout': 45, u'cadeau': 68, u'capcoz': 69, u'remboursement': 70, u'newyork': 71, u'halfmoonbay': 72, u'boston': 43, u'sante': 81, u'visite': 74, u'transfert': 75, u'voiture': 76, u'a': 77, u'placement': 78, u'restaurant': 35, u'dollars': 80, u'credit': 82, u'rome': 83, u'ouverture': 84, u'capecod': 85, u'road': 86}

# %%
data['df'][35:38]
# Out:
#          Date  Montant Moyen                           Libelle  \
# 35 2015-06-24   -32.09   NaN         CB FANDANGO.COM 22/06/15
# 36 2015-06-25   -49.29   NaN         CB YO.*BUS 6944 23/06/15
# 37 2015-06-28    -5.00   NaN  COTISATION MENSUELLE CARTE 2935
#
#                Etiquettes   Commentaires Unnamed: 6  \
# 35                 Cinema  Cinema Boston        NaN
# 36  Bus, Voyage, Tourisme    Bus NewYork        NaN
# 37                    LCL             NA        NaN
#
#                            Description          Etiquettes_list  \
# 35               Cinema, Cinema Boston                 [Cinema]
# 36  Bus, Voyage, Tourisme, Bus NewYork  [Bus, Voyage, Tourisme]
# 37                                 LCL                    [LCL]
#
#                         Description_list
# 35               [Cinema, Cinema Boston]
# 36  [Bus, Voyage, Tourisme, Bus NewYork]
# 37                                 [LCL]

# %% [raw]
# # Example
# group_idx = group_indices(data,['alimentaire','maison'])
# res = group_expenses(data,group_idx,plot=True)

# %%
cluster_labels = draw_graph(data)

# %%
clusters = cluster_details(data,cluster_labels, plot=False, verbose=False)
# Out:
# cloture : [u'cloture', u'livret', u'a']
# virement : [u'virement', u'frais']
# tourisme : [u'florence', u'italie', u'vol', u'avion', u'tourisme', u'visite']
# loisirs : [u'photo', u'loisirs', u'location', u'zipcar', u'hotel', u'photos', u'album', u'abonnement', u'cadeau', u'halfmoonbay', u'voiture', u'annuel', u'capecod']
# lcl : [u'pret', u'lcl', u'assurance', u'remboursement', u'interets']
# airbnb : [u'cambridge', u'soldex', u'airbnb', u'rome']
# coiffeur : [u'coiffeur', u'lasvegas', u'retrait', u'cash']
# restaurant : [u'brunch', u'creperie', u'paris', u'alimentaire', u'cantine', u'bar', u'restaurant', u'antony', u'cafe', u'dininghall', u'mit']
# lucile : [u'anniversaire', u'lucile', u'livre']
# maison : [u'ulock', u'velo', u'maison']
# cinema : [u'cinema', u'boston']
# telephone : [u'telephone', u'skype', u'sante', u'credit']
# internet : [u'aout', u'internet']
# transport : [u'taxi', u'caltrain', u'ratp', u'transport']
# voyage : [u'essence', u'bus', u'train', u'peage', u'trip', u'voyage', u'sncf', u'capcoz', u'newyork', u'road']
# na : ['na']
# usa : [u'usa', u'ava']
# transfert : [u'vie', u'tricount', u'bforbank', u'achat', u'transfert', u'placement', u'dollars', u'ouverture']

# %%
to_hide = ['transfert','lcl']

# %%
fig = plt.figure(figsize=(18,12))
fig_args = {'fig':fig, 'shape':[(len(clusters)+4)/5,5],'sub':0,'title':'cluster'}
monthly_avg = []
sub_nb = 0
to_show = []
for c in clusters:
    fig_args['sub'] = sub_nb+1
    fig_args['title'] = c['name']
    group_idx = c['idx']
    group_avg = group_monthly_analysis(data, group_idx, start_month=3, fig_args = fig_args)
    if not(np.any([item in c['lab'] for item in to_hide])):
        monthly_avg.append(group_avg)
        to_show.append(sub_nb)
    sub_nb += 1

monthly_avg = np.asarray(monthly_avg)
plt.show()

# %%
scaled_monthly_avg = monthly_avg / np.sum(monthly_avg,axis=0)

# %%
all_colors = ('darkorchid', 'yellowgreen', 'gold', 'lightskyblue', 'lightcoral','darkcyan','darkgoldenrod','darkgray','chocolate',
              'hotpink','turquoise','plum','khaki','steelblue','darkorange','lightgreen','lightsteelblue')

# %%
# Expenses
plt.figure(figsize=(10,10))
plt.title('Monthly expenses')
pie(scaled_monthly_avg[:,1],
    labels=[clusters[to_show[l]]['name']+ '  ' + "{:.0f}".format(monthly_avg[l,1]) for l in arange(len(to_show))],
    colors = all_colors,
    autopct='%1.1f%%', shadow=True, startangle=90)
plt.legend(loc='center right', bbox_to_anchor=(1.5, 0.5))
plt.show()

# %%
# Profits
plt.figure(figsize=(10,10))
plt.title('Monthly profits')
pie(scaled_monthly_avg[:,0],
    labels=[clusters[to_show[l]]['name']+ '  ' + "{:.0f}".format(monthly_avg[l,0]) for l in arange(len(to_show))],
    colors = all_colors,
    autopct='%1.1f%%', shadow=True, startangle=90)
plt.legend(loc='center right', bbox_to_anchor=(1.5, 0.5))
plt.show()
