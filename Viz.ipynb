# %%
from viz_tools import *
from main import *
from config import *
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = prepare_data(filename)
# Out:
# Vocabulary {u'taxi': 0, u'anniversaire': 1, u'cambridge': 2, u'vie': 3, u'photo': 4, u'ulock': 57, u'cloture': 6, u'caltrain': 7, u'florence': 8, u'brunch': 9, u'italie': 17, u'airbnb': 25, u'creperie': 11, u'usa': 12, u'paris': 13, u'alimentaire': 14, u'cinema': 15, u'cantine': 16, u'virement': 10, u'location': 19, u'essence': 20, u'pret': 22, u'lasvegas': 23, u'zipcar': 24, u'bus': 26, u'retrait': 27, u'internet': 61, u'photos': 29, u'train': 30, u'lcl': 31, u'bar': 32, u'tricount': 33, u'hotel': 28, u'annuel': 80, u'cash': 35, u'mit': 65, u'lucile': 36, u'x': 37, u'antony': 38, u'velo': 40, u'ratp': 41, u'vol': 42, u'coiffeur': 21, u'solde': 44, u'telephone': 45, u'livre': 68, u'skype': 47, u'interets': 74, u'cafe': 48, u'dininghall': 49, u'trip': 50, u'transport': 51, u'album': 52, u'voyage': 53, u'frais': 54, 'na': 55, u'avion': 56, u'bforbank': 5, u'ava': 58, u'sncf': 59, u'maison': 60, u'peage': 39, u'achat': 62, u'abonnement': 63, u'tourisme': 64, u'loisirs': 18, u'assurance': 66, u'livret': 67, u'aout': 46, u'cadeau': 69, u'capcoz': 70, u'remboursement': 71, u'newyork': 72, u'halfmoonbay': 73, u'boston': 43, u'sante': 82, u'visite': 75, u'transfert': 76, u'voiture': 77, u'a': 78, u'placement': 79, u'restaurant': 34, u'dollars': 81, u'credit': 83, u'rome': 84, u'ouverture': 85, u'capecod': 86, u'road': 87}

# %%
data['df'][:5]
# Out:
#         Date  Montant     Moyen                                    Libelle  \
# 0 2015-04-03  -279.93       NaN  CB RETRAIT DU 01/04/15 *MIT STR CAMBRIDGE
# 1 2015-04-07    -2.40       NaN                             PRLV SEPA SPB
# 2 2015-04-08  -273.65       NaN           CB RETRAIT DU 06/04/15 *MIT STR
# 3 2015-04-09    23.48  Virement         VIREMENT SOMMES DUES COMPTES CLOT
# 4 2015-04-20    90.00  Virement                    VIREMENT REMI LE PRIOL
#
#   Etiquettes   Commentaires Unnamed: 6               Description  \
# 0  Transfert  Achat Dollars        NaN  Transfert, Achat Dollars
# 1        LCL             NA        NaN                       LCL
# 2  Transfert  Achat Dollars        NaN  Transfert, Achat Dollars
# 3         NA             NA        NaN                        NA
# 4         NA             NA        NaN                        NA
#
#   Etiquettes_list            Description_list
# 0     [Transfert]  [Transfert, Achat Dollars]
# 1           [LCL]                       [LCL]
# 2     [Transfert]  [Transfert, Achat Dollars]
# 3            [NA]                        [NA]
# 4            [NA]                        [NA]

# %%
# Example
group_idx = group_indices(data,['alimentaire','maison'])
res = group_expenses(data,group_idx,plot=True)
# Out:
# Expenses for group : ['alimentaire', 'maison']
# Gained: 0 	Spent -1216.08 	Total: -1216.08

# %%
cluster_labels = draw_graph(data)

# %%
cluster_details(data,cluster_labels, plot=True)
# Out:
# Cluster 0
# Expenses for group : ['anniversaire', 'lucile', 'na']
# Gained: 122.45 	Spent -328.16 	Total: -205.71
# Cluster 1
# Expenses for group : ['virement', 'frais']
# Gained: 0 	Spent -4.4 	Total: -4.4
# C:\MyPrograms\Anaconda\lib\site-packages\matplotlib\axes\_base.py:2544: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=126.0, right=126.0
#   'left=%s, right=%s') % (left, right))
# Cluster 2
# Expenses for group : ['cinema', 'boston']
# Gained: 0 	Spent -46.49 	Total: -46.49
# Cluster 3
# Expenses for group : ['florence', 'italie', 'avion', 'tourisme', 'visite', 'sante']
# Gained: 0 	Spent -2045.35 	Total: -2045.35
# Cluster 4
# Expenses for group : ['photo', 'loisirs', 'zipcar', 'hotel', 'photos', 'album', 'abonnement', 'livre', 'cadeau', 'halfmoonbay', 'voiture', 'annuel', 'capecod']
# Gained: 0.17 	Spent -968.8 	Total: -968.63
# Cluster 5
# Expenses for group : ['pret', 'lcl', 'assurance', 'remboursement', 'interets']
# Gained: 20027.98 	Spent -1509.14 	Total: 18518.84
# Cluster 6
# Expenses for group : ['cambridge', 'airbnb', 'rome']
# Gained: 797.02 	Spent -345.8 	Total: 451.22
# Cluster 7
# Expenses for group : ['brunch', 'creperie', 'paris', 'alimentaire', 'cantine', 'bar', 'restaurant', 'antony', 'cafe', 'dininghall', 'mit']
# Gained: 0 	Spent -1398.51 	Total: -1398.51
# Cluster 8
# Expenses for group : ['coiffeur', 'lasvegas', 'retrait', 'cash']
# Gained: 0 	Spent -196.79 	Total: -196.79
# Cluster 9
# Expenses for group : ['x', 'solde']
# Gained: 7443.2 	Spent 0 	Total: 7443.2
# Cluster 10
# Expenses for group : ['velo', 'ulock', 'maison']
# Gained: 0 	Spent -469.18 	Total: -469.18
# Cluster 11
# Expenses for group : ['telephone', 'skype', 'credit']
# Gained: 0 	Spent -165.86 	Total: -165.86
# Cluster 12
# Expenses for group : ['aout', 'internet']
# Gained: 0 	Spent -93.07 	Total: -93.07
# Cluster 13
# Expenses for group : ['taxi', 'caltrain', 'ratp', 'transport']
# Gained: 0 	Spent -72.23 	Total: -72.23
# Cluster 14
# Expenses for group : ['location', 'essence', 'bus', 'train', 'peage', 'vol', 'trip', 'voyage', 'sncf', 'capcoz', 'newyork', 'road']
# Gained: 0 	Spent -1175.71 	Total: -1175.71
# Cluster 15
# Expenses for group : ['usa', 'ava']
# Gained: 0 	Spent -874.8 	Total: -874.8
# C:\MyPrograms\Anaconda\lib\site-packages\matplotlib\axes\_base.py:2544: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=80.0, right=80.0
#   'left=%s, right=%s') % (left, right))
# Cluster 16
# Expenses for group : ['cloture', 'livret', 'a']
# Gained: 4825.98 	Spent 0 	Total: 4825.98
# Cluster 17
# Expenses for group : ['vie', 'bforbank', 'tricount', 'achat', 'transfert', 'placement', 'dollars', 'ouverture']
# Gained: 29845.52 	Spent -45501.24 	Total: -15655.72
