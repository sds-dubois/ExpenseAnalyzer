# %%
from viz_tools import *
from main import *
from config import *
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = prepare_data(filename)
# Out:
# Vocabulary {u'taxi': 0, u'anniversaire': 1, u'cambridge': 2, u'mit': 71, u'vie': 3, u'photo': 4, u'ulock': 62, u'cloture': 6, u'caltrain': 7, u'florence': 8, u'brunch': 9, u'italie': 17, u'airbnb': 64, u'creperie': 11, u'usa': 12, u'paris': 13, u'alimentaire': 14, u'cinema': 15, u'cantine': 16, u'virement': 10, u'location': 19, u'las': 82, u'essence': 20, u'pret': 22, u'zipcar': 23, u'bus': 24, u'retrait': 25, u'internet': 66, u'photos': 27, u'vegas': 28, u'half': 29, u'cape': 31, u'lcl': 32, u'annuel': 86, u'bar': 33, u'tricount': 34, u'hotel': 26, u'cap': 35, u'cash': 36, u'bay': 38, u'lucile': 39, u'x': 40, u'antony': 84, u'velo': 43, u'ratp': 44, u'vol': 45, u'coiffeur': 21, u'solde': 47, u'telephone': 48, u'rome': 49, u'livre': 75, u'skype': 51, u'interets': 52, u'cafe': 53, u'dininghall': 54, u'ava': 30, u'transport': 56, u'album': 57, u'voyage': 58, u'frais': 59, 'na': 60, u'avion': 61, u'bforbank': 5, u'moon': 63, u'sncf': 41, u'maison': 65, u'peage': 42, u'new': 67, u'achat': 68, u'abonnement': 69, u'tourisme': 70, u'loisirs': 18, u'assurance': 72, u'livret': 74, u'trip': 55, u'aout': 50, u'cadeau': 76, u'remboursement': 77, u'boston': 46, u'sante': 78, u'york': 79, u'visite': 80, u'transfert': 81, u'voiture': 37, u'a': 83, u'placement': 85, u'restaurant': 73, u'dollars': 87, u'coz': 88, u'credit': 89, u'train': 90, u'ouverture': 91, u'cod': 92, u'road': 93}

# %%
data['df'][:5]
# Out:
#         Date  Montant     Moyen                                    Libelle  \
# 0 2015-04-03  -279.93       NaN  CB RETRAIT DU 01/04/15 *MIT STR CAMBRIDGE
# 1 2015-04-07    -2.40       NaN                             PRLV SEPA SPB
# 2 2015-04-08  -273.65       NaN           CB RETRAIT DU 06/04/15 *MIT STR
# 3 2015-04-09    23.48  Virement         VIREMENT SOMMES DUES COMPTES CLOT
# 4 2015-04-20    90.00  Virement                    VIREMENT REMI LE PRIOL
#
#   Etiquettes   Commentaires Unnamed: 6               Description  \
# 0  Transfert  Achat Dollars        NaN  Transfert, Achat Dollars
# 1        LCL             NA        NaN                       LCL
# 2  Transfert  Achat Dollars        NaN  Transfert, Achat Dollars
# 3         NA             NA        NaN                        NA
# 4         NA             NA        NaN                        NA
#
#   Etiquettes_list            Description_list
# 0     [Transfert]  [Transfert, Achat Dollars]
# 1           [LCL]                       [LCL]
# 2     [Transfert]  [Transfert, Achat Dollars]
# 3            [NA]                        [NA]
# 4            [NA]                        [NA]

# %%
# Example
group_idx = group_indices(data,['alimentaire','maison'])
res = group_expenses(data,group_idx,plot=True)
# Out:
# Expenses for group : ['alimentaire', 'maison']
# Gained: 0 	Spent -1216.08 	Total: -1216.08

# %%
cluster_labels = draw_graph(data)

# %%
cluster_details(data,cluster_labels, plot=True)
# Out:
# Cluster 0
# Expenses for group : ['virement', 'frais']
# Gained: 0 	Spent -4.4 	Total: -4.4
# C:\MyPrograms\Anaconda\lib\site-packages\matplotlib\axes\_base.py:2544: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=126.0, right=126.0
#   'left=%s, right=%s') % (left, right))
# Cluster 1
# Expenses for group : ['anniversaire', 'cinema', 'boston']
# Gained: 0 	Spent -84.49 	Total: -84.49
# Cluster 2
# Expenses for group : ['florence', 'italie', 'avion', 'tourisme', 'visite']
# Gained: 0 	Spent -1988.75 	Total: -1988.75
# Cluster 3
# Expenses for group : ['photo', 'loisirs', 'location', 'zipcar', 'hotel', 'photos', 'half', 'cape', 'voiture', 'bay', 'lucile', 'album', 'moon', 'abonnement', 'livre', 'cadeau', 'sante', 'annuel', 'cod']
# Gained: 0.17 	Spent -1025.4 	Total: -1025.23
# Cluster 4
# Expenses for group : ['pret', 'lcl', 'interets', 'assurance', 'remboursement']
# Gained: 20027.98 	Spent -1509.14 	Total: 18518.84
# Cluster 5
# Expenses for group : ['coiffeur', 'retrait', 'vegas', 'cash', 'na']
# Gained: 122.45 	Spent -471.05 	Total: -348.6
# Cluster 6
# Expenses for group : ['usa', 'ava']
# Gained: 0 	Spent -874.8 	Total: -874.8
# C:\MyPrograms\Anaconda\lib\site-packages\matplotlib\axes\_base.py:2544: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=80.0, right=80.0
#   'left=%s, right=%s') % (left, right))
# Cluster 7
# Expenses for group : ['x', 'solde']
# Gained: 7443.2 	Spent 0 	Total: 7443.2
# Cluster 8
# Expenses for group : ['velo', 'ulock', 'maison']
# Gained: 0 	Spent -469.18 	Total: -469.18
# Cluster 9
# Expenses for group : ['telephone', 'skype', 'credit']
# Gained: 0 	Spent -165.86 	Total: -165.86
# Cluster 10
# Expenses for group : ['taxi', 'caltrain', 'ratp', 'transport']
# Gained: 0 	Spent -72.23 	Total: -72.23
# Cluster 11
# Expenses for group : ['essence', 'bus', 'cap', 'sncf', 'peage', 'vol', 'trip', 'voyage', 'new', 'york', 'las', 'coz', 'train', 'road']
# Gained: 0 	Spent -1175.71 	Total: -1175.71
# Cluster 12
# Expenses for group : ['cambridge', 'rome', 'airbnb']
# Gained: 797.02 	Spent -345.8 	Total: 451.22
# Cluster 13
# Expenses for group : ['aout', 'internet']
# Gained: 0 	Spent -93.07 	Total: -93.07
# Cluster 14
# Expenses for group : ['brunch', 'creperie', 'paris', 'alimentaire', 'cantine', 'bar', 'cafe', 'dininghall', 'mit', 'restaurant', 'antony']
# Gained: 0 	Spent -1398.51 	Total: -1398.51
# Cluster 15
# Expenses for group : ['cloture', 'livret', 'a']
# Gained: 4825.98 	Spent 0 	Total: 4825.98
# Cluster 16
# Expenses for group : ['vie', 'bforbank', 'tricount', 'achat', 'transfert', 'placement', 'dollars', 'ouverture']
# Gained: 29845.52 	Spent -45501.24 	Total: -15655.72
